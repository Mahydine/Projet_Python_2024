# %% [markdown]
# # Interprétation et Visualisation

# %% [markdown]
# # répartition des scores cvss par gravité

# %%
import numpy as np
import matplotlib.pyplot as plt  # librairie 

# Exemple de données : Liste de scores CVSS fictifs
cvss_scores = [
    1.2, 2.8, 3.5, 4.0, 5.5, 6.3, 7.1, 8.5, 9.0, 9.8, 2.3, 4.5, 6.8, 7.9, 10.0
]

# Définir les intervalles (bins) et les couleurs associées
bins = [0, 3, 6, 8, 10]  # Plages personnalisées
colors = ["green", "yellow", "orange", "red"]
labels = ["Faible (0-3)", "Moyenne (4-6)", "Élevée (7-8)", "Critique (9-10)"]

# Compter les scores par tranche
counts, _ = np.histogram(cvss_scores, bins=bins)

# Créer l'histogramme coloré
plt.figure(figsize=(10, 6))
for i in range(len(bins) - 1):
    plt.bar(
        x=labels[i],  # Label de la catégorie
        height=counts[i],  # Nombre d'éléments dans la catégorie
        color=colors[i],  # Couleur associée
        label=labels[i]  # Légende
    )

# Ajouter des informations au graphique
plt.xlabel("Gravité CVSS")
plt.ylabel("Nombre de CVE")
plt.title("Répartition des scores CVSS par gravité")
plt.legend(title="Légende", loc="upper right")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Afficher le graphique
plt.show()

# %% [raw]
# interprétation

# %% [markdown]
# # Diagramme circulaire des types de vulnérabilités (CWE) :

# %% [markdown]
# # Courbe des scores EPSS :
